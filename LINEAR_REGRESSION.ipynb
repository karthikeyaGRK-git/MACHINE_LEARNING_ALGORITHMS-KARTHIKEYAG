# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeyaGRK-git/MACHINE_LEARNING_ALGORITHMS-KARTHIKEYAG/blob/main/LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(42)

X = np.random.rand(50, 1) * 100

Y = 3.5 * X + np.random.randn(50, 1) * 20

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.figure(figsize=(4,3))
plt.scatter(X, Y, color='GREEN', label='Data SETS')
plt.plot(X, Y_pred, color='BLUE', linewidth=2, label='Regression Line')
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Slope (Coefficient):", model.coef_[0][0])
print("Intercept:", model.intercept_[0])
# Out:
# Slope (Coefficient): 3.4553132007706204
# Intercept: 1.9337854893777546
